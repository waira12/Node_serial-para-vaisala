# %%
import pandas as pd

# %%
df = pd.read_csv('./15_de_julio_2022_Medellin_Col.csv')

# %%
df.drop(['CO (ug/m3)', 'PRES (hPa)', 'HUM (%RH)', 'TEMP (C)', 'Uptime (s)'], axis = 1).plot()
# Out:
# <AxesSubplot:>

# %%
datos=pd.read_csv('15_de_julio_2022_Medellin_Col.csv')
print (datos)
# Out:
#      NO2 (ug/m3)  CO (ug/m3)  O3 (ug/m3)  NO (ug/m3)  TEMP (C)  HUM (%RH)  \
# 0           35.8      1373.3         2.6        95.6      20.4       77.7
# 1           35.8      1387.9         1.4        96.5      20.4       77.7
# 2           35.8      1409.9         1.4        97.0      20.4       77.9
# 3           35.8      1411.3         1.4        97.8      20.5       77.6
# 4           36.3      1463.2         1.2        99.6      20.5       76.8
# ..           ...         ...         ...         ...       ...        ...
# 669         93.1      1670.0         5.2        44.5      24.0       62.0
# 670         93.1      1675.7         4.8        45.6      24.0       62.1
# 671         93.9      1687.0         5.2        45.7      24.0       62.1
# 672         94.4      1702.2         4.8        46.5      23.9       62.5
# 673         94.4      1702.5         4.0        47.7      23.9       62.1
#
#      PRES (hPa)  Uptime (s)                      Date
# ...

# %%
df.drop(['Uptime (s)', 'NO2 (ug/m3)', 'O3 (ug/m3)', 'NO (ug/m3)', 'PRES (hPa)', 'HUM (%RH)', 'TEMP (C)'], axis = 1).plot()
# Out:
# <AxesSubplot:>

# %%
df.drop(['Uptime (s)', 'NO2 (ug/m3)', 'O3 (ug/m3)', 'CO (ug/m3)', 'PRES (hPa)', 'HUM (%RH)', 'TEMP (C)'], axis = 1).plot()
# Out:
# <AxesSubplot:>

# %%
df.drop(['Uptime (s)', 'NO (ug/m3)', 'O3 (ug/m3)', 'CO (ug/m3)', 'PRES (hPa)', 'HUM (%RH)', 'TEMP (C)'], axis = 1).plot()
# Out:
# <AxesSubplot:>

# %%
df.drop(['Uptime (s)','NO2 (ug/m3)','NO (ug/m3)','CO (ug/m3)', 'PRES (hPa)', 'HUM (%RH)', 'TEMP (C)'], axis = 1).plot()
# Out:
# <AxesSubplot:>
