# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import statistics

# %%
df = pd.read_csv('./20-23_Mayo.csv')
#print (datos)
NO2= datos['NO2 (ug/m3)']
promNO2= statistics.mean(NO2)
print(promNO2)

CO= datos['CO (ug/m3)']
promCO= statistics.mean(CO)
print(promCO)

O3= datos['O3 (ug/m3)']
promO3= statistics.mean(O3)
print(promO3)

NO= datos['NO (ug/m3)']
promNO= statistics.mean(NO)
print(promNO)
# Out:
# 35.500947976878614
# 1103.8978497109827
# 10.567560693641619
# nan

# %%
Valores = [promCO]
Valores2 = [4000]
Etiquetas= ['CO']
rang = np.arange(len(Valores))
an = 0.3
fig, ax = plt.subplots()


ax.bar(rang -an/2, Valores, an, label='Prom medida')
ax.bar(rang +an/2, Valores2, an,  label='Referencia')
ax.set(ylabel='(ug/m3)')




#for i,j in zip(rang,Valores):
 #  ax.annotate(j, xy=(i -0.2, j +0.2))

#for i,j in zip(rang,Valores2):
 #  ax.annotate(j, xy=(i +0.2, j +0.2))

ax.set_title('grafico de barras')
ax.set_ylabel('cantidad de medida')
ax.set_xticks(rang)
ax.set_xticklabels(Etiquetas)
plt.legend()

# %%
Valores = [ NO.mean(), promNO2, promO3]
Valores2 = [30, 50, 56]
Etiquetas= ['NO', 'NO2','O3']
rang = np.arange(len(Valores))
an = 0.3
fig, ax = plt.subplots()


ax.bar(rang -an/2, Valores, an, label='Prom medida')
ax.bar(rang +an/2, Valores2, an,  label='Referencia')
ax.set(ylabel='(ug/m3)')

ax.set_title('grafico de barras')
ax.set_ylabel('cantidad de medida')
ax.set_xticks(rang)
ax.set_xticklabels(Etiquetas)
plt.legend()
