# %%
import pandas as pd

# %%
df = pd.read_csv('./26-31_Mayo.csv')
#print (datos)
#df['Date'] = pd.to_datetime(df['Date'])

# %%
#df.Date.dt.strftime('%H:%M %p')

# %%
df = pd.read_csv('./26-31_Mayo.csv')
#print (datos)

# %%
df.drop([ 'PRES (hPa)', 'HUM (%RH)', 'TEMP (C)', 'Uptime (s)'], axis = 1).plot()
# Out:
# <AxesSubplot:>

# %%
# df.drop(['NO2 (ug/m3)', 'CO (ug/m3)', 'O3 (ug/m3)', 'NO (ug/m3)', 'TEMP (C)',
#        'HUM (%RH)', 'PRES (hPa)', 'Uptime (s)'], axis = 1).plot()
df = pd.read_csv('./20-23_Mayo.csv')
#print (datos)
df.drop(['NO2 (ug/m3)', 'CO (ug/m3)', 'O3 (ug/m3)', 'NO (ug/m3)',
       'HUM (%RH)', 'Uptime (s)', 'PRES (hPa)'], axis = 1).plot()
# Out:
# <AxesSubplot:>

# %%
df.drop(['Uptime (s)', 'NO2 (ug/m3)', 'O3 (ug/m3)', 'NO (ug/m3)', 'PRES (hPa)', 'HUM (%RH)', 'TEMP (C)'], axis = 1).plot()
# Out:
# <AxesSubplot:>

# %%
df.drop(['Uptime (s)', 'NO2 (ug/m3)', 'O3 (ug/m3)', 'CO (ug/m3)', 'PRES (hPa)', 'HUM (%RH)', 'TEMP (C)'], axis = 1).plot()
# Out:
# <AxesSubplot:>

# %%
df.drop(['Uptime (s)', 'NO (ug/m3)', 'O3 (ug/m3)', 'CO (ug/m3)', 'PRES (hPa)', 'HUM (%RH)', 'TEMP (C)'], axis = 1).plot()
# Out:
# <AxesSubplot:>

# %%
df.drop(['Uptime (s)','NO2 (ug/m3)','NO (ug/m3)','CO (ug/m3)', 'PRES (hPa)', 'HUM (%RH)', 'TEMP (C)'], axis = 1).plot()
# Out:
# <AxesSubplot:>
