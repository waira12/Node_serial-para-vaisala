# %%
from mpl_toolkits.axes_grid1 import host_subplot
from mpl_toolkits import axisartist
import matplotlib.pyplot as plt
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as ticker

# %%
#datosmedidas = './15dejulio.csv'
#datos = pd.read_csv('./15dejulio.csv')
#datos.head('./15dejulio.csv')

# %%
datos = pd.read_csv('./Campaña-medida.csv')
Uptime= datos['./Campaña-medida.csv']

print (Uptime[2960:2965])
plt.plot(Uptime[2960:2965])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\LENOVO IDEAPAD i7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\LENOVO IDEAPAD i7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\LENOVO IDEAPAD i7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: './12 de julio.csv'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\LENOVO IDEAPAD i7\Desktop\node_serial\ejemplo2.ipynb Celda 3 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/LENOVO%20IDEAPAD%20i7/Desktop/node_serial/ejemplo2.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> datos = pd.read_csv('./12 de julio.csv')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/LENOVO%20IDEAPAD%20i7/Desktop/node_serial/ejemplo2.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> Uptime= datos['./12 de julio.csv']
#       <a href='vscode-notebook-cell:/c%3A/Users/LENOVO%20IDEAPAD%20i7/Desktop/node_serial/ejemplo2.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> print (Uptime[2960:2965])
#       <a href='vscode-notebook-cell:/c%3A/Users/LENOVO%20IDEAPAD%20i7/Desktop/node_serial/ejemplo2.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> plt.plot(Uptime[2960:2965])
#
# File c:\Users\LENOVO IDEAPAD i7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File c:\Users\LENOVO IDEAPAD i7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: './12 de julio.csv'

# %%
datos = pd.read_csv('./Campaña-medida.csv')

NO2= datos['NO2 (ug/m3)']

NO= datos['NO (ug/m3)']

CO= datos['CO (ug/m3)']

O3= datos['O3 (ug/m3)']

Uptime= datos['Uptime (s)']

#Dias= 
Etiquetas= ['julio 12','julio 12', 'julio 13' ,'julio 13','julio 14','julio 14','julio 15','julio 15']

Etiqueta2= ['6:00 julio 12','18:00 julio 12','6:00 julio 13','18:00 julio 13','6:00 julio 14','18:00 julio 14','6:00 julio 15','16:00 julio 15','17:30 julio 15']
Uptime[2962] = Uptime[2962]*10
# Out:
# C:\Users\LENOVO IDEAPAD i7\AppData\Local\Temp\ipykernel_16904\719340222.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Uptime[2962] = Uptime[2962]*10

# %%
from calendar import c


fig, ax = plt.subplots()


ax.plot(Uptime,NO2,label='NO2',c='dodgerblue',linestyle='dotted', alpha=0.8)
#ax.plot(Uptime,NO2,'o',label='NO2',c='dodgerblue',lw=0.2, alpha=0.8)
#ax.set(xlabel='')
ax.set(ylabel='(ug/m3)')


#ax1=ax.twinx()
#ax1.plot(Uptime,CO,label='CO',c='darkorange',linestyle='dashed',lw=1, alpha=1)
#ax1.set(ylabel='CO (ug/m3)')
#ax1.legend()
#ax1.yaxis.label.set_color('orange')
#ax1.tick_params(axis='y', colors='k')

ax2=ax.twinx()
ax2.spines["right"].set_position(('axes',1.2))
ax2.plot(Uptime,NO,label='NO',c='k',lw=.5, alpha=1)
ax2.set(ylabel='NO (ug/m3)')
ax2.legend(loc=5)
ax2.yaxis.label.set_color('k')
ax2.tick_params(axis='y', colors='k')

#ax3=ax.twix()


ax.plot(Uptime,O3,label='O3', c='r',lw=.5, alpha=0.8)
ax.legend(loc=5)


#ax.grid()
ax.legend()

plt.title("Campaña de medida 12-15 de Julio")
#plt.show()


ax.set_xticklabels(Etiquetas)#, rotation=90)

#ticks_x= ticker.FuncFormatter(lambda x,pos:'{:.0f}'.format(x/3849))
#ax1.xaxis.set_major_formatter(ticks_x)
plt.figure(figsize=(15,15))
fig.savefig('Campaña de medida 15 de Julio.png',dpi=800,figsize=(15,15))
# Out:
# C:\Users\LENOVO IDEAPAD i7\AppData\Local\Temp\ipykernel_16904\598484147.py:42: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(Etiquetas)#, rotation=90)
# C:\Users\LENOVO IDEAPAD i7\AppData\Local\Temp\ipykernel_16904\598484147.py:47: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "figsize" which is no longer supported as of 3.3 and will become an error in 3.6
#   fig.savefig('Campaña de medida 15 de Julio.png',dpi=800,figsize=(15,15))

# %%
#NO2
from calendar import c

fig, ax = plt.subplots()

ax.plot(Uptime,NO2,label='NO2',lw=1, alpha=0.8)
#ax.set(xlabel='Tiempo')
ax.set(ylabel='(ug/m3)')

ax.grid()
ax.legend()


ax.set_xticklabels(Etiquetas)#, rotation=90)
plt.title("NO2 12-13 de Julio")
fig.savefig('NO2 115 de Julio.png',dpi=600)
# Out:
# C:\Users\LENOVO IDEAPAD i7\AppData\Local\Temp\ipykernel_16904\2584140477.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(Etiquetas)#, rotation=90)

# %%
#CO
from calendar import c

fig, ax = plt.subplots()

ax.plot(Uptime,CO,label='CO',lw=1, alpha=0.8)
#ax.set(xlabel='Tiempo')
ax.set(ylabel='(ug/m3)')

ax.grid()
ax.legend()

ax.set_xticklabels(Etiquetas)#2, rotation=90)
plt.title("CO 12-15 de Julio")
fig.savefig('CO 15 de Julio.png',dpi=600)
# Out:
# C:\Users\LENOVO IDEAPAD i7\AppData\Local\Temp\ipykernel_5480\3219367828.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(Etiqueta2, rotation=90)

# %%
#NO
from calendar import c

fig, ax = plt.subplots()

ax.plot(Uptime,NO,label='NO',lw=1, alpha=0.8)
#ax.set(xlabel='Tiempo')
ax.set(ylabel='(ug/m3)')

ax.grid()
ax.legend()

ax.set_xticklabels(Etiquetas)#, rotation=90)
plt.title("NO 12-15 de Julio")
fig.savefig('NO 14-15 de Julio.png',dpi=600)
# Out:
# C:\Users\LENOVO IDEAPAD i7\AppData\Local\Temp\ipykernel_5480\1470754656.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(Etiqueta2, rotation=90)

# %%
#O3
from calendar import c

fig, ax = plt.subplots()

ax.plot(Uptime,O3,label='O3',lw=1, alpha=0.8)
#ax.set(xlabel='Tiempo')
ax.set(ylabel='(ug/m3)')

ax.grid()
ax.legend()


ax.set_xticklabels(Etiquetas)#2,rotation=90)
plt.title("O3 12-15 de Julio")
fig.savefig('O3 14-15 de Julio.png',dpi=600)
# Out:
# C:\Users\LENOVO IDEAPAD i7\AppData\Local\Temp\ipykernel_5480\1308252849.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(Etiqueta2,rotation=90)
